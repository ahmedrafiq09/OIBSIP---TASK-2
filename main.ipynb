# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

# %%
df_2020 = pd.read_csv("Unemployment_Rate_upto_11_2020.csv")
df_2020
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
df_india = pd.read_csv("Unemployment in India.csv")
df_india
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
plt.figure(figsize=(15,7))
sns.boxplot(df_2020)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,7))
sns.boxplot(df_india)
# Out:
# <Axes: >

# %%
sns.pairplot(df_2020)

# %%
sns.pairplot(df_india)

# %%
sns.lineplot(df_2020)
# Out:
# <Axes: >

# %%
sns.lineplot(df_india)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(50, 20))
sns.boxplot(x=df_2020['Region'], y=df_2020[' Estimated Labour Participation Rate (%)'], data=df)
plt.title('Box Plot: Region vs. Estimated Labour Participation Rate (%)')
plt.show()

# %%
plt.figure(figsize=(50, 20))
sns.boxplot(x=df_2020['Region'], y=df_2020[' Estimated Employed'], data=df)
plt.title('Box Plot: Region vs. Estimated Employed')
plt.show()

# %%
# Histogram for numerical variables
df_2020.select_dtypes(include=['int', 'float']).hist(figsize=(12, 8), bins=20)
plt.suptitle('Histograms of Numeric Variables', y=1.02)
plt.show()

# %%
plt.figure(figsize=(50, 20))
sns.boxplot(x=df_india['Region'], y=df_india[' Estimated Labour Participation Rate (%)'], data=df)
plt.title('Box Plot: Region vs. Estimated Labour Participation Rate (%)')
plt.show()

# %%
plt.figure(figsize=(50, 20))
sns.boxplot(x=df_india['Region'], y=df_india[' Estimated Employed'], data=df)
plt.title('Box Plot: Region vs. Estimated Employed')
plt.show()

# %%
# Histogram for numerical variables
df_india.select_dtypes(include=['int', 'float']).hist(figsize=(12, 8), bins=20)
plt.suptitle('Histograms of Numeric Variables', y=1.02)
plt.show()
